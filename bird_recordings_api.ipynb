# %%
import pandas as pd
import numpy as np
import folium
import streamlit as st

import requests
import os

# %%
puerto_rico_bird_recordings = pd.read_json('puerto_rico_recordings.json')
recordings_df = pd.DataFrame(puerto_rico_bird_recordings['recordings'].tolist())

# %%
recordings_df =recordings_df[recordings_df['lat'].notna()]

recordings_df['lat'] = recordings_df['lat'].replace('', np.nan)
recordings_df['lat'] = recordings_df['lat'].astype(float)

recordings_df['lng'] = recordings_df['lng'].replace('', np.nan)
recordings_df['lng'] = recordings_df['lng'].astype(float)

# %%
 
    
map_osm = folium.Map(location=[18.22, -66.59], zoom_start=10)

recordings_df.apply(lambda row:folium.Marker(location=[row["lat"], row["lng"]], 
                                              radius=10, interactive = True, 
                                              tooltip=(row['loc']),
                                              popup=f"Lattitude:{row['lat']}<br>"
                                                f"Longitude:{row['lng']}<br>"
                                                 f"Name:{row['loc']}<br>"
                                                 f"Organism:{row['en']}"
                                              ).add_to(map_osm), axis=1)
map_osm
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[5], line 3
#       1 map_osm = folium.Map(location=[18.22, -66.59], zoom_start=10)
# ----> 3 recordings_df.apply(lambda row:folium.Marker(location=[row["lat"], row["lng"]],
#       4                                               radius=10, interactive = True,
#       5                                               tooltip=(row['loc']),
#       6                                               popup=f"Lattitude:{row['lat']}<br>"
#       7                                                 f"Longitude:{row['lng']}<br>"
#       8                                                  f"Name:{row['loc']}<br>"
#       9                                                  f"Organism:{row['en']}"
#      10                                               ).add_to(map_osm), axis=1)
#      11 map_osm
#
# File d:\projects\project_files\bird_audio\.venv\Lib\site-packages\pandas\core\frame.py:10374, in DataFrame.apply(self, func, axis, raw, result_type, args, by_row, engine, engine_kwargs, **kwargs)
#   10360 from pandas.core.apply import frame_apply
#   10362 op = frame_apply(
#   10363     self,
#   10364     func=func,
#    (...)
#   10372     kwargs=kwargs,
#   10373 )
# > 10374 return op.apply().__finalize__(self, method="apply")
#
# File d:\projects\project_files\bird_audio\.venv\Lib\site-packages\pandas\core\apply.py:916, in FrameApply.apply(self)
#     913 elif self.raw:
#     914     return self.apply_raw(engine=self.engine, engine_kwargs=self.engine_kwargs)
# --> 916 return self.apply_standard()
#
# File d:\projects\project_files\bird_audio\.venv\Lib\site-packages\pandas\core\apply.py:1063, in FrameApply.apply_standard(self)
#    1061 def apply_standard(self):
#    1062     if self.engine == "python":
# -> 1063         results, res_index = self.apply_series_generator()
#    1064     else:
#    1065         results, res_index = self.apply_series_numba()
#
# File d:\projects\project_files\bird_audio\.venv\Lib\site-packages\pandas\core\apply.py:1081, in FrameApply.apply_series_generator(self)
#    1078 with option_context("mode.chained_assignment", None):
#    1079     for i, v in enumerate(series_gen):
#    1080         # ignore SettingWithCopy here in case the user mutates
# -> 1081         results[i] = self.func(v, *self.args, **self.kwargs)
#    1082         if isinstance(results[i], ABCSeries):
#    1083             # If we have a view on v, we need to make a copy because
#    1084             #  series_generator will swap out the underlying data
#    1085             results[i] = results[i].copy(deep=False)
#
# Cell In[5], line 3, in <lambda>(row)
#       1 map_osm = folium.Map(location=[18.22, -66.59], zoom_start=10)
# ----> 3 recordings_df.apply(lambda row:folium.Marker(location=[row["lat"], row["lng"]],
#       4                                               radius=10, interactive = True,
#       5                                               tooltip=(row['loc']),
#       6                                               popup=f"Lattitude:{row['lat']}<br>"
#       7                                                 f"Longitude:{row['lng']}<br>"
#       8                                                  f"Name:{row['loc']}<br>"
#       9                                                  f"Organism:{row['en']}"
#      10                                               ).add_to(map_osm), axis=1)
#      11 map_osm
#
# File d:\projects\project_files\bird_audio\.venv\Lib\site-packages\folium\map.py:359, in Marker.__init__(self, location, popup, tooltip, icon, draggable, **kwargs)
#     357 super().__init__()
#     358 self._name = "Marker"
# --> 359 self.location = validate_location(location) if location is not None else None
#     360 self.options = parse_options(
#     361     draggable=draggable or None, autoPan=draggable or None, **kwargs
#     362 )
#     363 if icon is not None:
#
# File d:\projects\project_files\bird_audio\.venv\Lib\site-packages\folium\utilities.py:101, in validate_location(location)
#      96         raise ValueError(
#      97             "Location should consist of two numerical values, "
#      98             f"but {coord!r} of type {type(coord)} is not convertible to float."
#      99         )
#     100     if math.isnan(float(coord)):
# --> 101         raise ValueError("Location values cannot contain NaNs.")
#     102 return [float(x) for x in coords]
#
# ValueError: Location values cannot contain NaNs.

# %%
url_list = list(recordings_df['file'])
id_list = list(recordings_df['id'])

# %%
# Function to download file from URL
def download_file(url, save_path):
    response = requests.get(url)
    if response.status_code == 200:
        with open(save_path, 'wb') as file:
            file.write(response.content)
        print(f"Downloaded {save_path}")
    else:
        print(f"Failed to download {url}")

# Function to download files from a list of URLs
def download_files_from_list(url_list, id_list, download_dir):
    os.makedirs(download_dir, exist_ok=True)  # Create download directory if not exist
    for url, file_id in zip(url_list, id_list):
        filename = f"{file_id}.mp3"  # Using id_list for filename
        save_path = os.path.join(download_dir, filename)
        download_file(url, save_path)



# Call the function to download files
download_files_from_list(url_list_3, id_list_3, 'audio_files')
# Out:
# Downloaded audio_files\100150.mp3
# Downloaded audio_files\45627.mp3
# Downloaded audio_files\805336.mp3
# Downloaded audio_files\793983.mp3
# Downloaded audio_files\455402.mp3
# Downloaded audio_files\46642.mp3
# Downloaded audio_files\45628.mp3
# Downloaded audio_files\48520.mp3
# Downloaded audio_files\33681.mp3
# Downloaded audio_files\32058.mp3
# Downloaded audio_files\713822.mp3
# Downloaded audio_files\682524.mp3
# Downloaded audio_files\33703.mp3
# Downloaded audio_files\33702.mp3
# Downloaded audio_files\33699.mp3
# Downloaded audio_files\793991.mp3
# Downloaded audio_files\308509.mp3
# Downloaded audio_files\308508.mp3
# Downloaded audio_files\308507.mp3
# Downloaded audio_files\33701.mp3
# Downloaded audio_files\46650.mp3
# Downloaded audio_files\46649.mp3
# Downloaded audio_files\46648.mp3
# Downloaded audio_files\796182.mp3
# Downloaded audio_files\308531.mp3
# Downloaded audio_files\173469.mp3
# Downloaded audio_files\46652.mp3
# Downloaded audio_files\32079.mp3
# Downloaded audio_files\32078.mp3
# Downloaded audio_files\173477.mp3
# Downloaded audio_files\46673.mp3
# Downloaded audio_files\46645.mp3
# Downloaded audio_files\32080.mp3
# Downloaded audio_files\32072.mp3
# Downloaded audio_files\32071.mp3
# Downloaded audio_files\9421.mp3
# Downloaded audio_files\32230.mp3
# Downloaded audio_files\682521.mp3
# Downloaded audio_files\308526.mp3
# Downloaded audio_files\308525.mp3
# Downloaded audio_files\308524.mp3
# Downloaded audio_files\32236.mp3
# Downloaded audio_files\32232.mp3
# Downloaded audio_files\32233.mp3
# Downloaded audio_files\173478.mp3
# Downloaded audio_files\32086.mp3
# Downloaded audio_files\794002.mp3
# Downloaded audio_files\46674.mp3
# Downloaded audio_files\46672.mp3
# Downloaded audio_files\32085.mp3
# Downloaded audio_files\32081.mp3
# Downloaded audio_files\373567.mp3
# Downloaded audio_files\344037.mp3
# Downloaded audio_files\344036.mp3
# Downloaded audio_files\308510.mp3
# Downloaded audio_files\173620.mp3
# Downloaded audio_files\173386.mp3
# Downloaded audio_files\46659.mp3
# Downloaded audio_files\173307.mp3
# Downloaded audio_files\173305.mp3
# Downloaded audio_files\32060.mp3
# Downloaded audio_files\9415.mp3
# Downloaded audio_files\805083.mp3
# Downloaded audio_files\713835.mp3
# Downloaded audio_files\173431.mp3
# Downloaded audio_files\173391.mp3
# Downloaded audio_files\173288.mp3
# Downloaded audio_files\46632.mp3
# Downloaded audio_files\46631.mp3
# Downloaded audio_files\33682.mp3
# Downloaded audio_files\32074.mp3
# Downloaded audio_files\32055.mp3
# Downloaded audio_files\32051.mp3
# Downloaded audio_files\877054.mp3
# Downloaded audio_files\757619.mp3
# Downloaded audio_files\736959.mp3
# Downloaded audio_files\455404.mp3
# Downloaded audio_files\46637.mp3
# Downloaded audio_files\32077.mp3
# Downloaded audio_files\805334.mp3
# Downloaded audio_files\33709.mp3
# Downloaded audio_files\737279.mp3
# Downloaded audio_files\737278.mp3
# Downloaded audio_files\682522.mp3
# Downloaded audio_files\308522.mp3
# Downloaded audio_files\308521.mp3
# Downloaded audio_files\173300.mp3
# Downloaded audio_files\173289.mp3
# Downloaded audio_files\100153.mp3
# Downloaded audio_files\48508.mp3
# Downloaded audio_files\805329.mp3
# Downloaded audio_files\173664.mp3
# Downloaded audio_files\46641.mp3
# Downloaded audio_files\46633.mp3
# Downloaded audio_files\33693.mp3
# Downloaded audio_files\32227.mp3
# Downloaded audio_files\178978.mp3
# Downloaded audio_files\100152.mp3
# Downloaded audio_files\32069.mp3
# Downloaded audio_files\9416.mp3
# Downloaded audio_files\796189.mp3
# Downloaded audio_files\46640.mp3
# Downloaded audio_files\33694.mp3
# Downloaded audio_files\32226.mp3
# Downloaded audio_files\178979.mp3
# Downloaded audio_files\890512.mp3
# Downloaded audio_files\890514.mp3
# Downloaded audio_files\890466.mp3
# Downloaded audio_files\890511.mp3
# Downloaded audio_files\884333.mp3
# Downloaded audio_files\890506.mp3
# Downloaded audio_files\884393.mp3
# Downloaded audio_files\211637.mp3
# Downloaded audio_files\455405.mp3
# Downloaded audio_files\781754.mp3
# Downloaded audio_files\781753.mp3
# Downloaded audio_files\894570.mp3
# Downloaded audio_files\781757.mp3
# Downloaded audio_files\781756.mp3
# Downloaded audio_files\781755.mp3
# Downloaded audio_files\747019.mp3

# %%
id_list = list(recordings_df['id'])

# %%
download_files_from_list(url_list_2, id_list_2, 'audio_files')
# Out:
# ---------------------------------------------------------------------------
# MissingSchema                             Traceback (most recent call last)
# Cell In[49], line 1
# ----> 1 download_files_from_list(url_list_2, id_list_2, 'audio_files')
#
# Cell In[32], line 17, in download_files_from_list(url_list, id_list, download_dir)
#      15 filename = f"{file_id}.mp3"  # Using id_list for filename
#      16 save_path = os.path.join(download_dir, filename)
# ---> 17 download_file(url, save_path)
#
# Cell In[32], line 3, in download_file(url, save_path)
#       2 def download_file(url, save_path):
# ----> 3     response = requests.get(url)
#       4     if response.status_code == 200:
#       5         with open(save_path, 'wb') as file:
#
# File d:\projects\project_files\bird_audio\.venv\Lib\site-packages\requests\api.py:73, in get(url, params, **kwargs)
#      62 def get(url, params=None, **kwargs):
#      63     r"""Sends a GET request.
#      64
#      65     :param url: URL for the new :class:`Request` object.
#    (...)
#      70     :rtype: requests.Response
#      71     """
# ---> 73     return request("get", url, params=params, **kwargs)
#
# File d:\projects\project_files\bird_audio\.venv\Lib\site-packages\requests\api.py:59, in request(method, url, **kwargs)
#      55 # By using the 'with' statement we are sure the session is closed, thus we
#      56 # avoid leaving sockets open which can trigger a ResourceWarning in some
#      57 # cases, and look like a memory leak in others.
#      58 with sessions.Session() as session:
# ---> 59     return session.request(method=method, url=url, **kwargs)
#
# File d:\projects\project_files\bird_audio\.venv\Lib\site-packages\requests\sessions.py:575, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     562 # Create the Request.
#     563 req = Request(
#     564     method=method.upper(),
#     565     url=url,
#    (...)
#     573     hooks=hooks,
#     574 )
# --> 575 prep = self.prepare_request(req)
#     577 proxies = proxies or {}
#     579 settings = self.merge_environment_settings(
#     580     prep.url, proxies, stream, verify, cert
#     581 )
#
# File d:\projects\project_files\bird_audio\.venv\Lib\site-packages\requests\sessions.py:486, in Session.prepare_request(self, request)
#     483     auth = get_netrc_auth(request.url)
#     485 p = PreparedRequest()
# --> 486 p.prepare(
#     487     method=request.method.upper(),
#     488     url=request.url,
#     489     files=request.files,
#     490     data=request.data,
#     491     json=request.json,
#     492     headers=merge_setting(
#     493         request.headers, self.headers, dict_class=CaseInsensitiveDict
#     494     ),
#     495     params=merge_setting(request.params, self.params),
#     496     auth=merge_setting(auth, self.auth),
#     497     cookies=merged_cookies,
#     498     hooks=merge_hooks(request.hooks, self.hooks),
#     499 )
#     500 return p
#
# File d:\projects\project_files\bird_audio\.venv\Lib\site-packages\requests\models.py:368, in PreparedRequest.prepare(self, method, url, headers, files, data, params, auth, cookies, hooks, json)
#     365 """Prepares the entire request with the given parameters."""
#     367 self.prepare_method(method)
# --> 368 self.prepare_url(url, params)
#     369 self.prepare_headers(headers)
#     370 self.prepare_cookies(cookies)
#
# File d:\projects\project_files\bird_audio\.venv\Lib\site-packages\requests\models.py:439, in PreparedRequest.prepare_url(self, url, params)
#     436     raise InvalidURL(*e.args)
#     438 if not scheme:
# --> 439     raise MissingSchema(
#     440         f"Invalid URL {url!r}: No scheme supplied. "
#     441         f"Perhaps you meant https://{url}?"
#     442     )
#     444 if not host:
#     445     raise InvalidURL(f"Invalid URL {url!r}: No host supplied")
#
# MissingSchema: Invalid URL '': No scheme supplied. Perhaps you meant https://?

# %%
len(id_list)
# Out:
# 444

# %%
id_list_2
# Out:
# ['173411',
#  '173407',
#  '877752',
#  '793982',
#  '713814',
#  '308501',
#  '173410',
#  '855668',
#  '713813',
#  '794001',
#  '344039',
#  '344038',
#  '308515',
#  '859263',
#  '173635',
#  '173629',
#  '163937',
#  '100146',
#  '32092',
#  '32091',
#  '9419',
#  '9418',
#  '373562',
#  '173618',
#  '173424',
#  '46662',
#  '32068',
#  '173688',
#  '173642',
#  '173467',
#  '173443',
#  '173441',
#  '173286',
#  '33691',
#  '33679',
#  '33678',
#  '32087',
#  '46671',
#  '781752',
#  '1192',
#  '48517',
#  '48514',
#  '46647',
#  '46646',
#  '48507',
#  '33696',
#  '308529',
#  '173625',
#  '173616',
#  '173613',
#  '100155',
#  '32244',
#  '459129',
#  '46657',
#  '173666',
#  '173429',
#  '32234',
#  '32090',
#  '173662',
#  '105981',
#  '105979',
#  '46651',
#  '370027',
#  '370030',
#  '370024',
#  '344045',
#  '308505',
#  '308504',
#  '173658',
#  '173653',
#  '173426',
#  '173376',
#  '173299',
#  '33697',
#  '806419',
#  '805338',
#  '737119',
#  '713816',
#  '173378',
#  '100158',
#  '32056',
#  '9424',
#  '9423',
#  '860593',
#  '33710',
#  '32084',
#  '46653',
#  '46654',
#  '877751',
#  '862702',
#  '713827',
#  '344043',
#  '308511',
#  '173423',
#  '173420',
#  '173416',
#  '173403',
#  '173400',
#  '100156',
#  '805340',
#  '805339',
#  '737062',
#  '308512',
#  '32067',
#  '173659',
#  '173456',
#  '173454',
#  '173450',
#  '33680',
#  '173668',
#  '173452',
#  '32057',
#  '32054',
#  '173413',
#  '45764',
#  '45753',
#  '46663',
#  '173679',
#  '173675',
#  '173678',
#  '173673',
#  '100147',
#  '32052',
#  '156985',
#  '46635',
#  '520191',
#  '308520',
#  '308519',
#  '308518',
#  '173660',
#  '100160',
#  '33692',
#  '46643',
#  '46634',
#  '33685',
#  '33684',
#  '48521',
#  '682523',
#  '173671',
#  '173661',
#  '46675',
#  '46644',
#  '33695',
#  '32229',
#  '48518',
#  '455403',
#  '362004',
#  '46664',
#  '362032',
#  '362031',
#  '362005',
#  '361998',
#  '173630',
#  '362025',
#  '173636',
#  '682525',
#  '308528',
#  '308527',
#  '173463']

# %%
len(id_list[322:444])
# Out:
# 122

# %%
url_list_2 = url_list[163:322]
id_list_2 = id_list[163:322]
url_list_3 = url_list[323:444]
id_list_3 = id_list[323:444]

# %%
id_list_2
# Out:
# ['',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'https://xeno-canto.org/794001/download',
#  'https://xeno-canto.org/344039/download',
#  'https://xeno-canto.org/344038/download',
#  'https://xeno-canto.org/308515/download',
#  'https://xeno-canto.org/859263/download',
#  'https://xeno-canto.org/173635/download',
#  'https://xeno-canto.org/173629/download',
#  'https://xeno-canto.org/163937/download',
#  'https://xeno-canto.org/100146/download',
#  'https://xeno-canto.org/32092/download',
#  'https://xeno-canto.org/32091/download',
#  'https://xeno-canto.org/9419/download',
#  'https://xeno-canto.org/9418/download',
#  'https://xeno-canto.org/373562/download',
#  'https://xeno-canto.org/173618/download',
#  'https://xeno-canto.org/173424/download',
#  'https://xeno-canto.org/46662/download',
#  'https://xeno-canto.org/32068/download',
#  'https://xeno-canto.org/173688/download',
#  'https://xeno-canto.org/173642/download',
#  'https://xeno-canto.org/173467/download',
#  'https://xeno-canto.org/173443/download',
#  'https://xeno-canto.org/173441/download',
#  'https://xeno-canto.org/173286/download',
#  'https://xeno-canto.org/33691/download',
#  'https://xeno-canto.org/33679/download',
#  'https://xeno-canto.org/33678/download',
#  'https://xeno-canto.org/32087/download',
#  'https://xeno-canto.org/46671/download',
#  'https://xeno-canto.org/781752/download',
#  'https://xeno-canto.org/1192/download',
#  'https://xeno-canto.org/48517/download',
#  'https://xeno-canto.org/48514/download',
#  'https://xeno-canto.org/46647/download',
#  'https://xeno-canto.org/46646/download',
#  'https://xeno-canto.org/48507/download',
#  'https://xeno-canto.org/33696/download',
#  'https://xeno-canto.org/308529/download',
#  'https://xeno-canto.org/173625/download',
#  'https://xeno-canto.org/173616/download',
#  'https://xeno-canto.org/173613/download',
#  'https://xeno-canto.org/100155/download',
#  'https://xeno-canto.org/32244/download',
#  'https://xeno-canto.org/459129/download',
#  'https://xeno-canto.org/46657/download',
#  'https://xeno-canto.org/173666/download',
#  'https://xeno-canto.org/173429/download',
#  'https://xeno-canto.org/32234/download',
#  'https://xeno-canto.org/32090/download',
#  'https://xeno-canto.org/173662/download',
#  'https://xeno-canto.org/105981/download',
#  'https://xeno-canto.org/105979/download',
#  'https://xeno-canto.org/46651/download',
#  'https://xeno-canto.org/370027/download',
#  'https://xeno-canto.org/370030/download',
#  'https://xeno-canto.org/370024/download',
#  'https://xeno-canto.org/344045/download',
#  'https://xeno-canto.org/308505/download',
#  'https://xeno-canto.org/308504/download',
#  'https://xeno-canto.org/173658/download',
#  'https://xeno-canto.org/173653/download',
#  'https://xeno-canto.org/173426/download',
#  'https://xeno-canto.org/173376/download',
#  'https://xeno-canto.org/173299/download',
#  'https://xeno-canto.org/33697/download',
#  'https://xeno-canto.org/806419/download',
#  'https://xeno-canto.org/805338/download',
#  'https://xeno-canto.org/737119/download',
#  'https://xeno-canto.org/713816/download',
#  'https://xeno-canto.org/173378/download',
#  'https://xeno-canto.org/100158/download',
#  'https://xeno-canto.org/32056/download',
#  'https://xeno-canto.org/9424/download',
#  'https://xeno-canto.org/9423/download',
#  'https://xeno-canto.org/860593/download',
#  'https://xeno-canto.org/33710/download',
#  'https://xeno-canto.org/32084/download',
#  'https://xeno-canto.org/46653/download',
#  'https://xeno-canto.org/46654/download',
#  'https://xeno-canto.org/877751/download',
#  'https://xeno-canto.org/862702/download',
#  'https://xeno-canto.org/713827/download',
#  'https://xeno-canto.org/344043/download',
#  'https://xeno-canto.org/308511/download',
#  'https://xeno-canto.org/173423/download',
#  'https://xeno-canto.org/173420/download',
#  'https://xeno-canto.org/173416/download',
#  'https://xeno-canto.org/173403/download',
#  'https://xeno-canto.org/173400/download',
#  'https://xeno-canto.org/100156/download',
#  'https://xeno-canto.org/805340/download',
#  'https://xeno-canto.org/805339/download',
#  'https://xeno-canto.org/737062/download',
#  'https://xeno-canto.org/308512/download',
#  'https://xeno-canto.org/32067/download',
#  'https://xeno-canto.org/173659/download',
#  'https://xeno-canto.org/173456/download',
#  'https://xeno-canto.org/173454/download',
#  'https://xeno-canto.org/173450/download',
#  'https://xeno-canto.org/33680/download',
#  'https://xeno-canto.org/173668/download',
#  'https://xeno-canto.org/173452/download',
#  'https://xeno-canto.org/32057/download',
#  'https://xeno-canto.org/32054/download',
#  'https://xeno-canto.org/173413/download',
#  'https://xeno-canto.org/45764/download',
#  'https://xeno-canto.org/45753/download',
#  'https://xeno-canto.org/46663/download',
#  'https://xeno-canto.org/173679/download',
#  'https://xeno-canto.org/173675/download',
#  'https://xeno-canto.org/173678/download',
#  'https://xeno-canto.org/173673/download',
#  'https://xeno-canto.org/100147/download',
#  'https://xeno-canto.org/32052/download',
#  'https://xeno-canto.org/156985/download',
#  'https://xeno-canto.org/46635/download',
#  'https://xeno-canto.org/520191/download',
#  'https://xeno-canto.org/308520/download',
#  'https://xeno-canto.org/308519/download',
#  'https://xeno-canto.org/308518/download',
#  'https://xeno-canto.org/173660/download',
#  'https://xeno-canto.org/100160/download',
#  'https://xeno-canto.org/33692/download',
#  'https://xeno-canto.org/46643/download',
#  'https://xeno-canto.org/46634/download',
#  'https://xeno-canto.org/33685/download',
#  'https://xeno-canto.org/33684/download',
#  'https://xeno-canto.org/48521/download',
#  'https://xeno-canto.org/682523/download',
#  'https://xeno-canto.org/173671/download',
#  'https://xeno-canto.org/173661/download',
#  'https://xeno-canto.org/46675/download',
#  'https://xeno-canto.org/46644/download',
#  'https://xeno-canto.org/33695/download',
#  'https://xeno-canto.org/32229/download',
#  'https://xeno-canto.org/48518/download',
#  'https://xeno-canto.org/455403/download',
#  'https://xeno-canto.org/362004/download',
#  'https://xeno-canto.org/46664/download',
#  'https://xeno-canto.org/362032/download',
#  'https://xeno-canto.org/362031/download',
#  'https://xeno-canto.org/362005/download',
#  'https://xeno-canto.org/361998/download',
#  'https://xeno-canto.org/173630/download',
#  'https://xeno-canto.org/362025/download',
#  'https://xeno-canto.org/173636/download',
#  'https://xeno-canto.org/682525/download',
#  'https://xeno-canto.org/308528/download',
#  'https://xeno-canto.org/308527/download',
#  'https://xeno-canto.org/173463/download']
